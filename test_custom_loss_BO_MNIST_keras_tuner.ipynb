# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasHLirio/TCC_II/blob/main/test_custom_loss_BO_MNIST_keras_tuner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Install and import the Keras Tuner.

# %%
# !pip install -q -U keras-tuner

# %%
import keras_tuner as kt

# %% [markdown]
# ## Download and prepare the dataset

# %%
(img_train, label_train), (img_test, label_test) = keras.datasets.mnist.load_data(path="mnist.npz")

# %%
from keras.utils import to_categorical

# Normalize pixel values between 0 and 1
img_train = img_train.astype('float32') / 255.0
img_test = img_test.astype('float32') / 255.0

# One-hot encode labels for categorical crossentropy function
label_train = to_categorical(label_train, num_classes=10)
label_test = to_categorical(label_test, num_classes=10)

# %% [markdown]
# ## Creating custom loss function

# %%
from keras import losses
class ChebyshevLoss(losses.Loss):
    def __init__(self, ideal_loss_point, weights, name="chebyshev_loss"):
        super().__init__(name=name)
        self.ideal_loss_point = ideal_loss_point
        self.weights = weights

    def call(self, y_true, y_pred):
        # Calculates cross entropy loss (error)
        error_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred, from_logits=True)

        # Calculates L2 regularization (complexity)
        l2_loss = tf.add_n([tf.nn.l2_loss(weight) for weight in self.model.trainable_weights])

        # Chebyshev Scalarization involves maximizing the minimum of weights
        # Chebyshev loss is essentially the largest weighted difference of each objective to the ideal points
        weighted_error_diff = self.weights[0] * (error_loss - self.ideal_loss_point[0])
        weighted_l2_diff = self.weights[1] * (l2_loss - self.ideal_loss_point[1])

        # Combining the loss components following the Chebyshev criterion
        chebyshev_loss = tf.maximum(weighted_error_diff, weighted_l2_diff)

        return chebyshev_loss

    def get_config(self):
        config = super(ChebyshevLoss, self).get_config()
        config.update({
            "ideal_loss_point": self.ideal_loss_point,
            "weights": self.weights
        })
        return config

# %% [markdown]
# ## Define the model

# %%
def model_builder(hp):

  # model hps
  hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-1,1e-2,1e-3])

  #model structure
  model = keras.Sequential()
  model.add(keras.layers.Flatten(input_shape=(28, 28)))
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(10))

  #loss function hps
  hp_wheights1 = hp.Float('loss_wgt1', min_value=0.5, max_value=1.0, step=0.05)
  hp_wheights2 = hp.Float('loss_wgt2', min_value=0.0, max_value=0.1, step=0.01)

  ideal_loss_point = (0.0, 0.0)
  weights=(hp_wheights1, hp_wheights2)

  custom_loss_cheb = ChebyshevLoss(ideal_loss_point=ideal_loss_point, weights=weights)
  custom_loss_cheb.model = model # associates a model to the loss function

  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=custom_loss_cheb,
                metrics=['accuracy'])

  return model

# %% [markdown]
# ## Instantiate the tuner and perform hypertuning

# %%
tuner = kt.BayesianOptimization(
    model_builder,
    objective='val_accuracy',
    max_trials=100,
    directory='my_dir_test',
    project_name='test_wheights',
    overwrite=True) #overwrites a saved project

# %% [markdown]
# Create a callback to stop training early after reaching a certain value for the validation loss.

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# Run the hyperparameter search

# %%
import time as t
search_start = t.time()

tuner.search(img_train, label_train, epochs=10, validation_split=0.4, callbacks=[stop_early])
# Out:
# Trial 100 Complete [00h 01m 02s]
# val_accuracy: 0.971666693687439
#
# Best val_accuracy So Far: 0.9749583601951599
# Total elapsed time: 02h 03m 40s

# %%
search_end = t.time()
search_duration = (search_end - search_start)/60

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"Search duration: {search_duration:.2f} minutes ")
# Out:
# Search duration: 123.67 minutes

# %% [markdown]
# ## Train the model
#
# Find the optimal number of epochs to train the model with the hyperparameters obtained from the search.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
hypermodel = tuner.hypermodel.build(best_hps)

fit_start = t.time()

history = hypermodel.fit(img_train, label_train, epochs=100, validation_split=0.4)
# Out:
# Epoch 1/100
# 1125/1125 [==============================] - 8s 7ms/step - loss: 0.1871 - accuracy: 0.9233 - val_loss: 0.1162 - val_accuracy: 0.9505
# Epoch 2/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0759 - accuracy: 0.9683 - val_loss: 0.0901 - val_accuracy: 0.9621
# Epoch 3/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.0473 - accuracy: 0.9800 - val_loss: 0.0836 - val_accuracy: 0.9640
# Epoch 4/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0338 - accuracy: 0.9859 - val_loss: 0.0681 - val_accuracy: 0.9711
# Epoch 5/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.0236 - accuracy: 0.9905 - val_loss: 0.0659 - val_accuracy: 0.9718
# Epoch 6/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0175 - accuracy: 0.9926 - val_loss: 0.0684 - val_accuracy: 0.9729
# Epoch 7/100
# 1125/1125 [==============================] - 5s 5ms/step - loss: 0.0131 - accuracy: 0.9944 - val_loss: 0.0780 - val_accuracy: 0.9703
# Epoch 8/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 0.0101 - accuracy: 0.9958 - val_loss: 0.0757 - val_accuracy: 0.9721
# Epoch 9/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0076 - accuracy: 0.9971 - val_loss: 0.0800 - val_accuracy: 0.9714
# Epoch 10/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0832 - val_accuracy: 0.9731
# Epoch 11/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0086 - accuracy: 0.9963 - val_loss: 0.0900 - val_accuracy: 0.9712
# Epoch 12/100
# 1125/1125 [==============================] - 6s 6ms/step - loss: 0.0041 - accuracy: 0.9983 - val_loss: 0.0803 - val_accuracy: 0.9747
# Epoch 13/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.0044 - accuracy: 0.9981 - val_loss: 0.0866 - val_accuracy: 0.9747
# Epoch 14/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.1099 - val_accuracy: 0.9690
# Epoch 15/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0070 - accuracy: 0.9964 - val_loss: 0.0886 - val_accuracy: 0.9748
# Epoch 16/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 0.1052 - val_accuracy: 0.9718
# Epoch 17/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.0039 - accuracy: 0.9983 - val_loss: 0.0946 - val_accuracy: 0.9731
# Epoch 18/100
# 1125/1125 [==============================] - 5s 5ms/step - loss: 0.0035 - accuracy: 0.9984 - val_loss: 0.0961 - val_accuracy: 0.9747
# Epoch 19/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 0.0053 - accuracy: 0.9977 - val_loss: 0.1168 - val_accuracy: 0.9727
# Epoch 20/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 0.
100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 6.6117e-07 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9793
# Epoch 70/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 4.6147e-07 - accuracy: 1.0000 - val_loss: 0.1448 - val_accuracy: 0.9795
# Epoch 71/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 3.2487e-07 - accuracy: 1.0000 - val_loss: 0.1458 - val_accuracy: 0.9796
# Epoch 72/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 2.2720e-07 - accuracy: 1.0000 - val_loss: 0.1463 - val_accuracy: 0.9797
# Epoch 73/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 1.5604e-07 - accuracy: 1.0000 - val_loss: 0.1470 - val_accuracy: 0.9795
# Epoch 74/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 1.0863e-07 - accuracy: 1.0000 - val_loss: 0.1486 - val_accuracy: 0.9797
# Epoch 75/100
# 1125/1125 [==============================] - 6s 6ms/step - loss: 7.6376e-08 - accuracy: 1.0000 - val_loss: 0.1495 - val_accuracy: 0.9795
# Epoch 76/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 5.3969e-08 - accuracy: 1.0000 - val_loss: 0.1499 - val_accuracy: 0.9795
# Epoch 77/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 3.8768e-08 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 0.9796
# Epoch 78/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 2.8082e-08 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9794
# Epoch 79/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 2.1534e-08 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 0.9797
# Epoch 80/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 1.6244e-08 - accuracy: 1.0000 - val_loss: 0.1554 - val_accuracy: 0.9795
# Epoch 81/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 1.2830e-08 - accuracy: 1.0000 - val_loss: 0.1559 - val_accuracy: 0.9796
# Epoch 82/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 1.0389e-08 - accuracy: 1.0000 - val_loss: 0.1570 - val_accuracy: 0.9796
# Epoch 83/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 8.5880e-09 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 0.9795
# Epoch 84/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 7.3526e-09 - accuracy: 1.0000 - val_loss: 0.1584 - val_accuracy: 0.9793
# Epoch 85/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 6.3628e-09 - accuracy: 1.0000 - val_loss: 0.1595 - val_accuracy: 0.9796
# Epoch 86/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 5.6419e-09 - accuracy: 1.0000 - val_loss: 0.1597 - val_accuracy: 0.9797
# Epoch 87/100
# 1125/1125 [==============================] - 6s 6ms/step - loss: 5.0392e-09 - accuracy: 1.0000 - val_loss: 0.1604 - val_accuracy: 0.9795
# Epoch 88/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 4.5131e-09 - accuracy: 1.0000 - val_loss: 0.1609 - val_accuracy: 0.9798
# Epoch 89/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 4.1955e-09 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9798
# Epoch 90/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 3.7945e-09 - accuracy: 1.0000 - val_loss: 0.1620 - val_accuracy: 0.9795
# Epoch 91/100
# 1125/1125 [==============================] - 5s 5ms/step - loss: 3.5094e-09 - accuracy: 1.0000 - val_loss: 0.1622 - val_accuracy: 0.9797
# Epoch 92/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 3.3124e-09 - accuracy: 1.0000 - val_loss: 0.1621 - val_accuracy: 0.9796
# Epoch 93/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 3.0736e-09 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9797
# Epoch 94/100
# 1125/1125 [==============================] - 7s 6ms/step - loss: 2.8650e-09 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9797
# Epoch 95/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 2.6633e-09 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9798
# Epoch 96/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 2.5915e-09 - accuracy: 1.0000 - val_loss: 0.1637 - val_accuracy: 0.9798
# Epoch 97/100
# 1125/1125 [==============================] - 5s 4ms/step - loss: 2.3921e-09 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 0.9797
# Epoch 98/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 2.3017e-09 - accuracy: 1.0000 - val_loss: 0.1641 - val_accuracy: 0.9798
# Epoch 99/100
# 1125/1125 [==============================] - 6s 5ms/step - loss: 2.1719e-09 - accuracy: 1.0000 - val_loss: 0.1642 - val_accuracy: 0.9798
# Epoch 100/100
# 1125/1125 [==============================] - 6s 6ms/step - loss: 2.0607e-09 - accuracy: 1.0000 - val_loss: 0.1644 - val_accuracy: 0.9797

# %%
fit_end = t.time()
fit_duration = (fit_end - fit_start)/60

print(f"Training duration: {fit_duration:.2f} minutes ")
# Out:
# Training duration: 9.83 minutes

# %%
eval_result = hypermodel.evaluate(img_test, label_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1244 - accuracy: 0.9826

# %%
print("------------ SUMMARY ------------\n")
print(f"*Best Hyperparameters found:")
for key, value in best_hps.values.items():
 print(key,":",value)
print(f'\n*Hypermodel Evaluation:\nTest loss: {eval_result[0]:.3f} \nTest accuracy: {100*eval_result[1]:.2f} %')
print(f"\n*Execution times:\nHyperparameter searching time: {search_duration:.2f} minutes \nHypermodel training time: {fit_duration:.2f} minutes")
# Out:
# ------------ SUMMARY ------------
#
# *Best Hyperparameters found:
# units : 320
# learning_rate : 0.001
# loss_wgt1 : 0.7
# loss_wgt2 : 0.0
#
# *Hypermodel Evaluation:
# Test loss: 0.124
# Test accuracy: 98.26 %
#
# *Execution times:
# Hyperparameter searching time: 123.67 minutes
# Hypermodel training time: 9.83 minutes

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['val_accuracy'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epochs ',fontsize=12)
plt.legend(['Val Acc', 'Val Loss'],fontsize=12)
plt.title('Accuracy and Loss Curves',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Accuracy and Loss Curves')

# %%
plt.figure(figsize=[8,4])
plt.plot(history.history['loss'],'r',linewidth=2.0)
plt.plot(history.history['val_loss'],'b',linewidth=2.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.title('Loss Curves',fontsize=14)

print('\n')

plt.figure(figsize=[8,4])
plt.plot(history.history['accuracy'],'r',linewidth=2.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.title('Accuracy Curves',fontsize=14)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')
